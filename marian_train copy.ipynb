# %%
import os
import re
import ast
import glob
import json
import random
import cutlet
import argparse
import MeCab
from collections import Counter
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from convert_romaji import Romaji2Kana

import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import KFold, train_test_split

import tensorflow as tf
from tensorflow.keras.layers import (
    Input,
    Dense, 
    TimeDistributed)

from transformers import (
    BertJapaneseTokenizer,
    TFBertModel,
    GradientAccumulator,
    logging)

def seed_everything(SEED):
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)
    print("Random seed set.")

seed_everything(42)
tf.get_logger().setLevel('FATAL')
logging.set_verbosity_error()
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Random seed set.

# %%
def ArgParser():
    parser = argparse.ArgumentParser()

    # Dataset
    parser.add_argument("--main_dir", default="E://Datasets/Language_model")
    parser.add_argument("--random_state", default=42)
    parser.add_argument("--n_shards", default=20)
    parser.add_argument("--n_samples", default=250000)
    parser.add_argument("--test_size", default=0.2)
    parser.add_argument("--vocab_size", default=4000)
    parser.add_argument("--batch_size", default=64)
    parser.add_argument("--buffer_size", default=1024)

    # Scheduler
    parser.add_argument("--epochs", default=20)
    parser.add_argument("--learning_rate", default=1e-4)
    parser.add_argument("--lr_start", default=1e-8)
    parser.add_argument("--lr_min", default=1e-8)
    parser.add_argument("--lr_max", default=1e-4)
    parser.add_argument("--n_cycles", default=0.5)
    parser.add_argument("--warmup_epochs", default=2)
    parser.add_argument("--sustain_epochs", default=0)

    args = parser.parse_known_args()[0]

    n_train = int(args.n_samples * (1 - args.test_size))
    n_val = int(args.n_samples * args.test_size)
    train_steps = int(np.ceil(n_train / args.batch_size))
    val_steps = int(np.ceil(n_val / args.batch_size))
    
    # Trainer
    parser.add_argument("--n_train", default=n_train)
    parser.add_argument("--n_val", default=n_val)
    parser.add_argument("--train_steps", default=train_steps)  
    parser.add_argument("--val_steps", default=val_steps)

    return parser.parse_known_args()[0]

args = ArgParser()
args
# Out:
# Namespace(batch_size=64, buffer_size=1024, epochs=20, learning_rate=0.0001, lr_max=0.0001, lr_min=1e-08, lr_start=1e-08, main_dir='E://Datasets/Language_model', n_cycles=0.5, n_samples=250000, n_shards=20, n_train=200000, n_val=50000, random_state=42, sustain_epochs=0, test_size=0.2, train_steps=3125, val_steps=782, vocab_size=4000, warmup_epochs=2)

# %% [markdown]
# # Data Preparation

# %%
class BertDataset:
    def __init__(self):
        self.main_dir = "D:\School-stuff\Sem-2\PR-Project\HoloASR\Datasets"
        opus_ja_paths = glob.glob(f"{self.main_dir}\OPUS100-dataset\*.ja")
        tatoeba_ja_paths = glob.glob(f"{self.main_dir}\Tatoeba-dataset\*.ja")
        self.jesc_path = f"{self.main_dir}/JESC-dataset/raw"
        self.ja_paths = opus_ja_paths + tatoeba_ja_paths
        self.kanji_unicode = self.get_kanji_unicode()
        self.katsu = cutlet.Cutlet()
        self.katsu.use_foreign_spelling = False

        tqdm.pandas()
        self.data = pd.DataFrame({"raw_text": self.get_data()})

        # Remove rows that contains non-kanji characters
        self.data = self.data[self.data['raw_text'].progress_apply(self.check_kanji)]   

        # Remove words within parenthesis
        parenthesis =  r"\（.*\）|\(.*\)|\「.*\」|\『.*\』"
        self.data = self.data[~self.data['raw_text'].str.contains(parenthesis)]

        # Remove punctuations from sentences
        self.data['raw_text'] = self.data['raw_text'].progress_apply(self.clean_kanji)

        # Converts kanji to hiragana sentences
        self.data['hira_text'] = self.data['raw_text'].progress_apply(self.kanji2hira)

        # Remove null rows
        self.data = self.data[~(self.data['raw_text']=="") | ~(self.data['hira_text']=="")]
        self.data = self.data.dropna().reset_index(drop=True)

        # Generate vocab file
        self.vocab_file = r"E:\Datasets\Language_model\bert_vocab.txt"
        self.get_vocab(self.data)

        # Construct tokenizer
        self.tokenizer = BertJapaneseTokenizer(
            vocab_file=self.vocab_file,
            do_lower_case=False,
            do_word_tokenize=False,
            do_subword_tokenize=True,
            word_tokenizer_type="mecab",
            subword_tokenizer_type="character")

        # Tokenize inputs and labels
        self.data['input_ids'] = self.data['hira_text'].progress_apply(
            lambda x: self.tokenizer(x).input_ids)
        self.data['label_ids'] = self.data['raw_text'].progress_apply(
            lambda x: self.tokenizer(x).input_ids)

        # Apply padding to either input or labels to same length
        new_input_ids, new_label_ids = [], []
        for row_idx in tqdm(range(len(self.data)), total=len(self.data)):
            input_ids, label_ids = self.pad_longest(row_idx)
            new_input_ids.append(input_ids)
            new_label_ids.append(label_ids)

        self.data['input_ids'] = new_input_ids
        self.data['label_ids'] = new_label_ids
        self.data['input_len'] = self.data['input_ids'].apply(len)

        # Remove rows that has unknown tokens
        self.data = self.data[~self.data['input_ids'].apply(
            lambda x: self.tokenizer.unk_token_id in x)]
        self.data = self.data[~self.data['label_ids'].apply(
            lambda x: self.tokenizer.unk_token_id in x)]
        self.data.reset_index(drop=True, inplace=True)

        # Save to csv
        self.data.to_csv(
            r"E:\Datasets\Language_model\bert_data.csv", 
            encoding="utf-8", index=False)

    def get_kanji_unicode(self):
        vocab = set()
        with open(f"{self.main_dir}\kanji_unicode.txt", encoding="utf-8") as f:
            lines = f.readlines()
            for line in lines:
                for char in line.split()[1:]:
                    vocab.add(char)
        return "|".join(sorted(vocab))

    def get_data(self):
        ja_lines = []
        for ja_path in self.ja_paths:
            with open(ja_path, "r", encoding="utf-8") as f:
                for line in f.readlines():
                    line = line.strip("\n| ")
                    ja_lines.append(line)
        with open(self.jesc_path, "r", encoding="utf-8") as f:
            texts = [text.split("\t") for text in f.readlines()]
            for _, line in texts:
                line = line.strip("\n| ")
                ja_lines.append(line)
        return ja_lines

    def check_kanji(self, sentence):
        pattern = f"[^{self.kanji_unicode}]"
        if re.match(pattern, sentence) == None:
            return True
        else:
            return False
    
    def clean_kanji(self, sentence):
        sentence = "".join(sentence.split())
        pattern = r"[・\。\！\.\？\、]"
        sentence = re.sub(pattern, "", sentence)
        return sentence

    def kanji2hira(self, sentence):
        try:
            sentence = self.katsu.romaji(sentence)
            sentence = sentence.replace(" ", "").lower()
            sentence = Romaji2Kana(sentence)
        except:
            sentence = None
        return sentence

    def get_vocab(self, data):
        vocab = []
        texts = data['raw_text'].tolist() + data['hira_text'].tolist()
        for text in tqdm(texts):
            for char in text:
                vocab.append(char)

        tokens = ["[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]"]
        
        for i in Counter(vocab).most_common():
            if i[0] in self.kanji_unicode:
                tokens.append(i[0])
            else:
                continue

        with open(self.vocab_file, "w", encoding="utf-8") as f:
            for token in tokens[:args.vocab_size]:
                f.write(token + "\n")    

    def pad_longest(self, row):
        input_len = len(self.data['input_ids'][row])
        label_len = len(self.data['label_ids'][row])
        input_ids = self.data['input_ids'][row]
        label_ids = self.data['label_ids'][row]
        if label_len > input_len:
            pad_width = label_len - input_len
            input_ids = np.pad(
                self.data['input_ids'][row], pad_width=(0, pad_width)).tolist()
        elif label_len < input_len:
            pad_width = input_len - label_len
            label_ids = np.pad(
                self.data['label_ids'][row], pad_width=(0, pad_width)).tolist()
        return input_ids, label_ids

# data = BertDataset().data
# data

# %% [markdown]
# # Data Loading

# %%
class TFRWriter():
    def __init__(self, args):
        self.args = args
        self.data = self.get_data()

    def get_data(self):
        tqdm.pandas()
        data = pd.read_csv(r"E:\Datasets\Language_model\bert_data.csv")
        data = data.dropna().reset_index(drop=True)
        data['input_ids'] = data['input_ids'].progress_apply(ast.literal_eval)
        data['label_ids'] = data['label_ids'].progress_apply(ast.literal_eval)
        data = data.query(f"input_len <= {data['input_len'].quantile(0.90)}")
        data = data.sample(n=self.args.n_samples, random_state=self.args.random_state)
        data = data.sort_values(by="input_len", ascending=True, ignore_index=True)
        return data[['input_ids', 'label_ids']]

    def _bytes_feature(self, value):
        """Returns a bytes_list from a string / byte."""
        if isinstance(value, type(tf.constant(0))):
            value = value.numpy()
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

    def serialize_example(self, *args):
        feature = {
            'input_ids': self._bytes_feature(args[0]),
            'attention_mask': self._bytes_feature(args[1]),
            'label_ids': self._bytes_feature(args[2])}

        example_proto = tf.train.Example(
            features=tf.train.Features(feature=feature))
        return example_proto.SerializeToString()

    def get_shards(self):
        skf = KFold(n_splits=self.args.n_shards, shuffle=False)
        return [j for i,j in skf.split(self.data)]

    def get_shard_data(self, samples):
        for sample in samples:
            input_ids = tf.convert_to_tensor(
                self.data['input_ids'][sample], dtype=tf.int32)
            attention_mask = tf.where(input_ids != 0, x=1, y=0)
            label_ids = tf.convert_to_tensor(
                self.data['label_ids'][sample], dtype=tf.int32)
            yield {
                "input_ids": tf.io.serialize_tensor(input_ids),
                "attention_mask": tf.io.serialize_tensor(attention_mask),
                "label_ids": tf.io.serialize_tensor(label_ids)}

    def write(self):
        for shard, samples in tqdm(enumerate(self.get_shards()), total=self.args.n_shards):
            with tf.io.TFRecordWriter(f"{self.args.main_dir}/bert_tfrec/shard_{shard+1}.tfrec") as f:
                for sample in self.get_shard_data(samples):
                    example = self.serialize_example(
                        sample['input_ids'],
                        sample['attention_mask'],
                        sample['label_ids'])
                    f.write(example)

# TFRWriter(args).write()

# %%
class DataLoader:
    def __init__(self, args):
        self.files = glob.glob(args.main_dir + "/bert_tfrec/*.tfrec")
        self.args = args
        self.AUTOTUNE = tf.data.AUTOTUNE
        self.train_files, self.val_files = train_test_split(
            self.files, test_size=args.test_size, shuffle=True,
            random_state=args.random_state)
        self.train = self.get_train()
        self.val = self.get_val()

    def read_tfrecord(self, example):
        feature_description = {
            'input_ids': tf.io.FixedLenFeature([], tf.string),
            'attention_mask': tf.io.FixedLenFeature([], tf.string),
            'label_ids': tf.io.FixedLenFeature([], tf.string)
            }
        
        example = tf.io.parse_single_example(example, feature_description)
        example['input_ids'] = tf.io.parse_tensor(
            example['input_ids'], out_type=tf.int32)
        example['attention_mask'] = tf.io.parse_tensor(
            example['attention_mask'], out_type=tf.int32) 
        example['label_ids'] = tf.io.parse_tensor(
            example['label_ids'], out_type=tf.int32)
        return example

    def load_dataset(self, files):
        ignore_order = tf.data.Options()
        ignore_order.experimental_deterministic = False
        dataset = tf.data.TFRecordDataset(files)
        dataset = dataset.with_options(ignore_order)
        dataset = dataset.map(self.read_tfrecord, num_parallel_calls=self.AUTOTUNE)
        return dataset

    def get_train(self):
        dataset = self.load_dataset(self.train_files)
        dataset = dataset.padded_batch(
            self.args.batch_size,
            padded_shapes={
                'input_ids': [None],
                'attention_mask': [None],
                'label_ids': [None]
            },
            padding_values={
                'input_ids': tf.constant(0, dtype=tf.int32),
                'attention_mask': tf.constant(0, dtype=tf.int32),
                'label_ids': tf.constant(0, dtype=tf.int32)
            })        
        dataset = dataset.shuffle(self.args.buffer_size)
        dataset = dataset.prefetch(self.AUTOTUNE)
        return dataset

    def get_val(self):
        dataset = self.load_dataset(self.val_files)
        dataset = dataset.padded_batch(
            self.args.batch_size,
            padded_shapes={
                'input_ids': [None],
                'attention_mask': [None],
                'label_ids': [None]
            },
            padding_values={
                'input_ids': tf.constant(0, dtype=tf.int32),
                'attention_mask': tf.constant(0, dtype=tf.int32),
                'label_ids': tf.constant(0, dtype=tf.int32)
            })
        dataset = dataset.shuffle(self.args.buffer_size)
        dataset = dataset.cache()
        dataset = dataset.prefetch(self.AUTOTUNE)
        return dataset

# train = DataLoader(args).train

# inputs = next(iter(train))
# print("input_ids shape:", inputs['input_ids'].shape)
# print("attention_mask shape:", inputs['attention_mask'].shape)
# print("label_ids shape:", inputs['label_ids'].shape)

# %% [markdown]
# # Model Training

# %%
class CERMetric(tf.keras.metrics.Metric):
    def __init__(self, name="CER", **kwargs):
        super(CERMetric, self).__init__(name=name,  **kwargs)
        self.accumulator = self.add_weight(name="total_cer", initializer="zeros")
        self.counter = self.add_weight(name="cer_count", initializer="zeros")    

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        hypothesis = tf.cast(tf.sparse.from_dense(y_pred), dtype=tf.int32)

        # Convert dense to sparse tensor for edit_distance function
        truth = tf.RaggedTensor.from_tensor(y_true, padding=0).to_sparse()

        # Calculate Levenshtein distance
        distance = tf.edit_distance(hypothesis, truth, normalize=True)

        # Add distance and number of samples to variables
        self.accumulator.assign_add(tf.reduce_sum(distance))
        self.counter.assign_add(len(y_true))

    def result(self):
        # Divides accumulated distance scores against number of samples passed,
        # mimics mean reduction over batch
        return tf.math.divide_no_nan(self.accumulator, self.counter)   
    
    def reset_state(self):
        self.accumulator.assign(0.0)
        self.counter.assign(0.0)

class CosineDecayWithWarmup(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, args):
        self.args = args

    def __call__(self, epoch):  
        if epoch < self.args.warmup_epochs:
            lr = ((self.args.lr_max - self.args.lr_start) / self.args.warmup_epochs) * epoch + self.args.lr_start
        elif epoch < (self.args.warmup_epochs + self.args.sustain_epochs):
            lr = self.args.lr_max
        else:
            progress = ((epoch - self.args.warmup_epochs - self.args.sustain_epochs) / 
            (self.args.epochs - self.args.warmup_epochs - self.args.sustain_epochs))
            lr = (self.args.lr_max-self.args.lr_min) * (0.5 * (1.0 + tf.math.cos((22/7) * 
                self.args.n_cycles * 2.0 * progress)))
            if self.args.lr_min is not None:
                lr = tf.math.maximum(self.args.lr_min, lr)
        return lr

    def plot(self):
        epochs = range(self.args.epochs+1)
        lr = [self(epoch) for epoch in epochs]
        plt.plot(epochs, lr)
        plt.xlabel("learning_rate")
        plt.ylabel("epochs")
        plt.show()

CosineDecayWithWarmup(args).plot()

# %%
class Trainer:
    def __init__(self, args):
        self.args = args
        self.train_dataset = DataLoader(args).train
        self.val_dataset = DataLoader(args).val

        self.tokenizer = BertJapaneseTokenizer(
            vocab_file=r"E:\Datasets\Language_model\bert_vocab.txt",
            do_lower_case=False,
            do_word_tokenize=False,
            do_subword_tokenize=True,
            word_tokenizer_type="mecab",
            subword_tokenizer_type="character")
        
        self.model = self.Kana2Kanji(args)
        
        self.optimizer = tf.keras.optimizers.Adam(CosineDecayWithWarmup(args))
        self.loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(
            from_logits=False)
        self.cer_metric = CERMetric()

        self.model_name = f"model_{int(self.args.n_samples/1000)}k"
        self.log_path = f"{self.args.main_dir}/bert_model_weights/{self.model_name}.csv"
        if not os.path.exists(self.log_path):
            print("Log file created.")
            columns = "epoch,loss,cer,val_loss,val_cer\n"
            with open(self.log_path, "a") as f:
                f.write(columns)

    def Kana2Kanji(self, args):
        input_ids = Input(type_spec=tf.TensorSpec(
            shape=(args.batch_size, None), dtype=tf.int32), name="input_ids")
        mask = Input(type_spec=tf.TensorSpec(
            shape=(args.batch_size, None), dtype=tf.int32), name="attention_mask")

        bert = TFBertModel.from_pretrained(
            "cl-tohoku/bert-base-japanese-char",
            # num_attention_heads=16,
            # num_hidden_layers=24,
            output_hidden_states=False,
            output_attentions=False,
            name="bert_model")

        x = bert(input_ids=input_ids, attention_mask=mask).last_hidden_state
        x = TimeDistributed(Dense(args.vocab_size, activation="softmax"), name="output")(x, mask=mask)

        return tf.keras.Model(inputs=[input_ids, mask], outputs=x, name="Kana2Kanji")

    def decoder(self, labels, logits):
        labels = self.tokenizer.batch_decode(labels, skip_special_tokens=True)
        logits = tf.argmax(logits, axis=-1)
        logits = self.tokenizer.batch_decode(logits, skip_special_tokens=True)
        return labels, logits

    def display(self, epoch, t_labels, t_logits, v_labels, v_logits):
        print("-" * 129)
        print("Training")
        for y_true, y_pred in zip(t_labels, t_logits):
            print(f"Target:    {y_true.replace(' ', '')}")
            print(f"Predicted: {y_pred.replace(' ', '')}") 

        print("\nValidation")
        for y_true, y_pred in zip(v_labels, v_logits):
            print(f"Target:    {y_true.replace(' ', '')}")
            print(f"Predicted: {y_pred.replace(' ', '')}")
        print("-" * 129)
        
    def fit(self):
        # Checkpointing
        self.ckpt_dir = f"{self.args.main_dir}/bert_checkpoints"
        self.ckpt = tf.train.Checkpoint(self.model)
        self.ckpt_manager = tf.train.CheckpointManager(
            checkpoint=self.ckpt, directory=self.ckpt_dir, max_to_keep=5)

        if self.ckpt_manager.latest_checkpoint:
            self.start_epoch = int(self.ckpt_manager.latest_checkpoint.split("-")[-1])
            self.ckpt.restore(self.ckpt_manager.latest_checkpoint)
            print(f"Resuming from epoch {self.start_epoch + 1}...")
        else:
            self.start_epoch = 0
            print("Starting from epoch 1...")

        for epoch in range(self.start_epoch, self.args.epochs+1):
            print(f"Epoch {epoch+1}/{self.args.epochs}: Learning rate @ {self.optimizer.lr(epoch):.2e}")
            stateful_metrics = ["loss", "cer", "val_loss", "val_cer"]
            progbar = tf.keras.utils.Progbar(
                self.args.train_steps, interval=0.05,
                stateful_metrics=stateful_metrics)

            # Training loop
            for step, t_batch in enumerate(self.train_dataset):
                t_input_ids = t_batch['input_ids']
                t_attention_mask = t_batch['attention_mask']
                t_labels = t_batch['label_ids']
                with tf.GradientTape() as tape:
                    t_logits = self.model(
                        [t_input_ids, t_attention_mask],
                        training=True)
                    t_loss = self.loss_fn(
                        t_labels, t_logits, sample_weight=t_attention_mask)
                    self.cer_metric.update_state(t_labels, t_logits)
                gradients = tape.gradient(t_loss, self.model.trainable_weights)
                self.optimizer.apply_gradients(zip(gradients, self.model.trainable_weights))
                t_cer = self.cer_metric.result()
                t_values = [("loss", t_loss), ("cer", t_cer)]
                progbar.update(step, values=t_values, finalize=False)
            
            t_labels, t_logits = self.decoder(t_labels, t_logits)
            self.cer_metric.reset_state()

            # Validation loop
            for v_batch in self.val_dataset:
                v_input_ids = v_batch['input_ids']
                v_attention_mask = v_batch['attention_mask']
                v_labels = v_batch['label_ids']
                v_logits = self.model(
                    [v_input_ids, v_attention_mask],
                    training=False)
                v_loss = self.loss_fn(
                    v_labels, v_logits, sample_weight=v_attention_mask)
                self.cer_metric.update_state(v_labels, v_logits)
            v_labels, v_logits = self.decoder(v_labels, v_logits)
            v_cer = self.cer_metric.result()
            v_values = [
                ("loss", t_loss),
                ("cer", t_cer),
                ("val_loss", v_loss),
                ("val_cer", v_cer)]
            progbar.update(self.args.train_steps, values=v_values, finalize=True)
            self.cer_metric.reset_state()

            # Print sample transcriptions for both loops
            self.display(epoch, t_labels, t_logits, v_labels, v_logits)

            # Checkpointing
            self.ckpt.save(file_prefix=f"{self.ckpt_dir}/{self.model_name}")

            # Logging
            log = f"{epoch+1},{t_loss},{t_cer},{v_loss},{v_cer}\n"
            with open(self.log_path, "a") as f:
                f.write(log)

            save_path = f"{self.args.main_dir}/bert_model_weights"
            self.model.save_weights(f"{save_path}/{self.model_name}_{epoch+1}.h5")

Trainer(args).fit()
# Out:
# Resuming from epoch 2...
# Epoch 2/20: Learning rate @ 5.00e-05
# 3125/3125 [==============================] - 1026s 328ms/step - loss: 1.1958 - cer: 0.2489 - val_loss: 0.7260 - val_cer: 0.1479
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    貴方はたった今皆を破滅の道へ導いた
# Predicted: あなたはたった今名をを滅のの道へへいたた
# Target:    でもここに座るならお前は飲んで話しはしない
# Predicted: でもここに座るならお前は飲んで話ししない
# Target:    でも超カワイイ子が何を話すか分からないわ
# Predicted: でも調家かいいいががをすすかかからなないわ
# Target:    私が普段着るような服ではなかったけれど
# Predicted: 私が船段きるよよな服でななっったけけど
# Target:    私たちに英語の歌をうたってくれませんか
# Predicted: 私たちに語語を歌歌っっててれまませか
# Target:    オックスフォードであなたに会うように言われました
# Predicted: フッックフォーででなたににうううう言言言ましたたフ
# Target:    彼女はわたしのおくりものを大変喜んだ
# Predicted: 彼女はわたしの贈り物をを変変よんんだ
# Target:    傷つかなければね殺人容疑が晴れたようだね
# Predicted: 傷つかなければね殺人に疑ががれれよよだね
# Target:    といったフレーズばかりを使う傾向があります
# Predicted: と言ったフレイズばりりを使う向ががあまます
# Target:    彼女はこの残酷な世界には馴染まなかった
# Predicted: 彼女はこの残国な世界にはじじなかっった
# Target:    お前の痙攣を共有したくなかっただけだ
# Predicted: お前の経令を共有ししくななっっただだだ
# Target:    ところがドラゴンライダー達は傲慢に成り出し
# Predicted: ところがドラゴンライダーたははゴ慢になりりりし
# Target:    最強の祓魔師に与えられる称号だ
# Predicted: 最強の払いまにえええれるる仕合合
# Target:    お尋ねの権利は当方にはぞくしておりません
# Predicted: お尋ねの権利は当方ににはししておりままん
# Target:    全体の半分の州しか参加していません
# Predicted: 全体の半分の主かかさ加していいません
# Target:    オフィスで話すわよし装着したでもう一つは
# Predicted: オフィスですすすししししたたもも一一つつつ
# Target:    そう俺は得意じゃないライフジャケットは必須
# Predicted: そう俺は得意じないいライラジャャットトッッす
# Target:    はい久美さんもすてきな男性を見つけてください
# Predicted: はいくみんもも敵敵な男をを見けけてくささい
# Target:    彼らは大義にコミットし部族にコミットします
# Predicted: 彼らは大議にコみっとシ部ににコっととまま
# Target:    アヘンヘロインがアフガニスタンで作られています
# Predicted: アヘンヘェインンガフガニススンでらられてています
# Target:    この夏私はコロラドのロッキー山脈で
# Predicted: この夏私ははロドのロッキキさ
# Target:    眠れぬ夜をもたらすのは野生人ではないのだ
# Predicted: 眠れぬ夜をもたらすのはや人人ははないのだ
# Target:    娘が来て鍵を使って父親を発見した
# Predicted: 娘が敵て鍵を使って父父発見見したた
# Target:    ええとピート自動車がカフェの右隣りにあるわ
# Predicted: ええとピーとと時車ががのの右どなりあある
# Target:    そしてあなたチンケなツラの皮が厚いクソ野郎
# Predicted: そしてあなたちんなならかかがあつくくろ郎郎
# Target:    ジョニー冗談言うな君こそ第一候補さ
# Predicted: ジョニー冗談ニなな君そそだ一小ささ
# Target:    学校の先生も守りに入るタイプですから
# Predicted: 学校の先生も守り入いいタイプですすから
# Target:    私は明日彼のところを訪れるつもりです
# Predicted: 私は明す彼のととを訪れれつもりりすす
# Target:    英語には日本語から入った語がいくつかある
# Predicted: 英語には日本語から入ったたががくくかああ
# Target:    これが奥様のために私が出来る全てです
# Predicted: これが奥様のために私ができるすべてです
# Target:    私はその結果に全然満足していない
# Predicted: 私はその結にに全全満ししていなな
# Target:    花ばさみも剪定ばさみもフローリストナイフも
# Predicted: 花ばさも先先定ささももロロリリトトなフももも
# Target:    彼女は彼が賄賂を受け取るだろうと思った
# Predicted: 彼女は彼がワ色を受けけるだだうと思っっ
# Target:    仕事自体は何事もなくあっさり終わったんだ
# Predicted: 仕事自たはななごもなくくありり終終たたんだ
# Target:    クリアしたければ気合を入れろでないと脱落だ
# Predicted: クリアしたければき合を入れでなないだだだだだ
# Target:    ネットで検索して出てきたサイトに連絡して
# Predicted: ネットで検索して出てたササイトに絡してて
# Target:    問題はそのことが認識されていないことです
# Predicted: 問題はそのこがが認しされれいいいことでです
# Target:    トムの誕生日にプレゼントを贈りたいんです
# Predicted: トムの誕生日にプレゼントト送りたいんですす
# Target:    たぶん最初に出会うグリムがあなたかも知れない
# Predicted: たぶ最最初に出うググムががななかももれないい
# Target:    サンプルを採って照合分析に回しました
# Predicted: サンプルを取ってし合分分に回ままました
# Target:    彼女と別れたり愛する人を失ったとき
# Predicted: 彼女と別かたり合する人人を失っった
# Target:    私の事件は全てこの会社と関係が
# Predicted: 私の事件は全てての会社と関係係がが
# Target:    これほどまでに傷つけたやつはお前が初めてだ
# Predicted: これほどまでに傷つたた奴はお前前始めててだ
# Target:    血管の中からみなぎる力でやり遂げるのさ
# Predicted: 結果の中からなる力ででやりりげるる
# Target:    最後になりますが私は固く信じています
# Predicted: 最後になりますが私は確信信ていいます
# Target:    もちろん俺はこれをクロノールのためにやってるんだ
# Predicted: もちろんれれれれれ苦のノのののたにややてるんだ
# Target:    父親がクソでも受験で点数さえ取りゃな
# Predicted: 父親がそででも件でで転すさとととななな
# Target:    今日本橋から九段下線に入りました
# Predicted: 今に本番しから段段任にに入まししし
# Target:    真面目にやりたければ流行にのってはいけない
# Predicted: ま面目にやりたければ流行に乗てははけけない
# Target:    あなたの忠実さに審議会は感謝します
# Predicted: あなたの中実さに神議会会感謝しします
# Target:    そういう言い方はやめてよ傷癒えてないんだから
# Predicted: そう言ういい方はやめてて気づいえなないんだから
# Target:    学校とか家のこととか他にもいろいろあって
# Predicted: 学校とかへのこととかかにもいいろろっって
# Target:    社長はどうせフェラーリとか乗り回してんだろ
# Predicted: 社長はどせエラアリとかのりりししてんろろ
# Target:    口論を目撃したと証言したんですよね
# Predicted: 後論を目撃したと言言したんんですねね
# Target:    病棟を訪ね患者たちに死の話をして
# Predicted: 病頭を訪ね感ゃたちちにし話ししして
# Target:    オニール君はスーパーマンを見つけたそりゃすごい
# Predicted: おニいる君はスパパーンを見つけたたそゃゃごい
# Target:    すると砂漠はこんな風に再構成されました
# Predicted: すると砂漠はこんな風にに最成さされまた
# Target:    持ってった方がいい必要かはハーシェルが決める
# Predicted: 持ってった方がいい必要ははハーールルがめめ
# Target:    彼は自分の予定を私のに合わせてくれた
# Predicted: 彼は自分の予定を私の合合せせてくれた
# Target:    ソユーズは損傷してるがドライブには使える
# Predicted: ソユーズは損象してるがドライブに使えるる
# Target:    ボッスンはガニ股ぎみに歩くことが多いからな
# Predicted: ボッスんががにたみみにあくくこが多いかから
# Target:    彼は子供達に紛れてポツンと座っていたの
# Predicted: 彼は子供たちにまれててつんんっっってのの
# Target:    新しい番組の作成で忙しかったので
# Predicted: 新しい番組の作生で忙ししかったので
# Target:    ワシは空のハンターだ優れた視力を持ってる
# Predicted: ワシは空のハンタだ出すれたた力力を持っるる
#
# Validation
# Target:    甲の損は乙の得
# Predicted: 公のソンはおののく
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソンフ上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこえ歩いて行けます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あずずずりがががす
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 年書からの日日
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早くや郎う
# Target:    己の真価を見せよ
# Predicted: 俺の信化を見せよよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大週えより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君はやせてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたな変さん
# Target:    えぇマキャリスターです
# Predicted: エマキャリスターですス
# Target:    レース用の箒だよ
# Predicted: レースよう方き気だよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技からうせろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜ぞを見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアと呼ばせない
# Target:    他の方法を探す
# Predicted: 他の方法を探すす
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き止めることにっって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念なことだ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き話された父親
# Target:    誤解しないでください
# Predicted: 誤解しないで下ださい
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数まいそそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だその三ババイザー
# Target:    いい人生を送れよ
# Predicted: いい人生を送れよ
# Target:    声も変える必要が
# Predicted: 声も帰る必要要が
# Target:    果てしない空と大地
# Predicted: ハてしないらとだ一
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中中す
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の話だ
# Target:    チェコフワープできるか
# Predicted: ヘココフはププきるるかる
# Target:    いやお前には出来ない
# Predicted: いやお前には出きない
# Target:    捨てられん大好きだろ
# Predicted: 捨てられん大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップが行こう
# Target:    ここまでやってこられた
# Predicted: ここまでやってこられた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今げいなのよ
# Target:    この機械は価値がない
# Predicted: この機会は価ちがない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 3/20: Learning rate @ 1.00e-04
# 3125/3125 [==============================] - 1025s 328ms/step - loss: 0.8384 - cer: 0.2029 - val_loss: 0.5987 - val_cer: 0.1273
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    次郎は富士山をスケッチした
# Predicted: 自郎は不父山をスけちした
# Target:    または誰かが持ち去ったんだ
# Predicted: または誰かが持ちさったんだ
# Target:    ネットを越えて広がりました
# Predicted: ネットを超えて広がりました
# Target:    ここにはコンマが必要です
# Predicted: ここには今ンが必要要です
# Target:    謎のプリズムスターデビュー
# Predicted: 謎のプリズムスターデビュュ
# Target:    瞬間ごとに異なります
# Predicted: 瞬間言ににことなりま
# Target:    作品で遊んだりできます
# Predicted: 作品で遊んだりききます
# Target:    だから真剣に取り組んでる
# Predicted: だから真験に取り組んでる
# Target:    子供の時と変わっていない
# Predicted: 子供の時時とわっっいいい
# Target:    デュエルディスクの反応探知
# Predicted: デュルルィススの反のー
# Target:    懐が厳しいんだ返せ
# Predicted: 太とが厳しいんだえ
# Target:    今やめなければ殺されるぞ
# Predicted: 今やめなければ殺されるぞ
# Target:    でも探してみるって言ってた
# Predicted: でも探して見るって行ってた
# Target:    これまでは機械学習で
# Predicted: これまでは機会学習で
# Target:    うん本当だよすいませんね
# Predicted: うん本当だよすいませんね
# Target:    あれはそう容易ではなかった
# Predicted: あれはそう用意ではなかった
# Target:    ママの部屋からベンが見えたの
# Predicted: ママの部屋からベが見えたの
# Target:    警察くじはお前の勝ちだ
# Predicted: 警察く地はお前の勝だだ
# Target:    委員会の決定なんです
# Predicted: 委員会の決定なでです
# Target:    あそこで自転車を借りよう
# Predicted: あそこで自転車を借りよう
# Target:    やっぱりコミケは行ってんのね
# Predicted: やっぱり込みけは行ってんのね
# Target:    いますよ確実にこの中に
# Predicted: 今すよ確実にこの中にに
# Target:    じゃあリオ先輩はどうして
# Predicted: じゃあリオ先輩はどうして
# Target:    丸の大きさは人口です
# Predicted: 丸ルの大きさ人人ででで
# Target:    本当の事を言ってるのよ
# Predicted: 本当の事とを言っるるのよ
# Target:    小さなリッチテキストエディタ
# Predicted: 小さなり地地キスエえた
# Target:    農場ってあの農場
# Predicted: 農上ってあの農場
# Target:    これが終り次第また会える
# Predicted: これが終わりしだいまた会え
# Target:    はいなかなか面白いですね
# Predicted: はいなかなか面白いですす
# Target:    すんませんバカにしたわけじゃ
# Predicted: すんませんバカに下たわけじ
# Target:    できるだけ早く始めなさい
# Predicted: できるだけ早く初めめなさ
# Target:    彼は行動を起こすフィンチ
# Predicted: 彼は行動を起コスィンン
# Target:    私もママと一緒だわ
# Predicted: 私もマまと一緒だだ
# Target:    友達もたくさんできました
# Predicted: 友達もたくさんできました
# Target:    気持ちの整理をつけるための
# Predicted: 気持ちの整理をつけるための
# Target:    意識の第二の特徴は
# Predicted: 意識の大題の特特はは
# Target:    ふじ色オレンジ黄土色
# Predicted: 藤いロロンンンーーーー
# Target:    それは明らかではないのです
# Predicted: それは明らかではないのです
# Target:    僕の衣裳部屋で話そう
# Predicted: 僕の医傷部屋で話そそう
# Target:    女房の脚は見てないぞ
# Predicted: に防の足は見てないぞ
# Target:    これは国際プロジェクトです
# Predicted: これは国際プロジェェトトすす
# Target:    とても大切な事だったの
# Predicted: とても大切な事とだったの
# Target:    しかし別のオープン側から
# Predicted: しかし別のオオプンがかから
# Target:    あなたは容疑者じゃないわ
# Predicted: あなたは容疑者ゃゃないわ
# Target:    子どもたちのためなら良くても
# Predicted: 子供たちのためなら良くても
# Target:    息子よ車を買ってやろう
# Predicted: 息子よ車を買っっややうう
# Target:    急いで出ていった感じだな
# Predicted: 急い出出て行った感じだな
# Target:    俺もそれなりに遊んできた
# Predicted: 俺ももれなりに遊んできた
# Target:    突然は無理よすぐには無理
# Predicted: 突然は無理よすぐには理り
# Target:    目立たない人の方がいいよ
# Predicted: 目立たない人の方がいいよ
# Target:    行かない行かないんだカラオケ
# Predicted: 行かないいかないんだからおけ
# Target:    アンタが農夫のハーシェルだな
# Predicted: あんたがのオフのハーチェルだな
# Target:    分かるだろアーチーを見てみろ
# Predicted: 分かるだろあーチチを見見みみ
# Target:    ミンコスキーと話がしたい
# Predicted: ミンコスキーと話ががたい
# Target:    側の人を見てみてください
# Predicted: 側の人を見てみてください
# Target:    重要な事なのは分かる
# Predicted: 重要なことののは分るる
# Target:    ネクロディフェンダーを墓地へ
# Predicted: ネクロイエンダダををちチン
# Target:    ミート保安官事務所です
# Predicted: ミートホ安ン事務所です
# Target:    父さんが母さんを殺した
# Predicted: 父さんが母さんを殺した
# Target:    サイモン博士をはじめとする
# Predicted: サイモン博士を始めめするる
# Target:    彼女を馬鹿にした感じだ
# Predicted: 彼女をバカにした感じだ
# Target:    なぜ花粉シーズンを過ぎても
# Predicted: なぜか分ンいズをを過ても
# Target:    下がってから決着を付ける
# Predicted: 下っててらけ着着をつるる
# Target:    昔馴染みの警官がいる
# Predicted: 昔なじミの警官がいる
#
# Validation
# Target:    甲の損は乙の得
# Predicted: コのソソンはおのの得
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン夫上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いて行けます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あらずずりがががる
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 年書からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早くやろう
# Target:    己の真価を見せよ
# Predicted: おの進化を見見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大週へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないのの
# Target:    だって君はやせてるし
# Predicted: だって君はやせてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたな変さん
# Target:    えぇマキャリスターです
# Predicted: エマキャリススーーです
# Target:    レース用の箒だよ
# Predicted: レース用ののきだだよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技からせせろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の予ぞを見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュュと呼ばばない
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き止めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念なことだ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すはでも今はまだ
# Target:    引き離された父親
# Predicted: 引き話された父親
# Target:    誤解しないでください
# Predicted: 誤解しないで下ださい
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数毎なそそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそののンバイザザ
# Target:    いい人生を送れよ
# Predicted: いい人生を送れよ
# Target:    声も変える必要が
# Predicted: 声も変える必要が
# Target:    果てしない空と大地
# Predicted: 果てしな急空とだ一
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しまスジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中中す
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: シェコフはププできるかる
# Target:    いやお前には出来ない
# Predicted: いやお前にはできない
# Target:    捨てられん大好きだろ
# Predicted: 捨てられん大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップが行こ
# Target:    ここまでやってこられた
# Predicted: ここまでやってこられた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今ゲーなのよ
# Target:    この機械は価値がない
# Predicted: この機会は勝値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 4/20: Learning rate @ 9.92e-05
# 3125/3125 [==============================] - 981s 314ms/step - loss: 0.7366 - cer: 0.1720 - val_loss: 0.6093 - val_cer: 0.1154
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    行ってみようかなこの戸を動かせれば
# Predicted: 言ってみようかなこのとを動せせれ
# Target:    自分で思うよりも友達がいたな
# Predicted: 自分で思うよりも友達いいた
# Target:    電子回路でもできるということです
# Predicted: 電子回路でもできるというここです
# Target:    なぜならそれはこの先私たちが
# Predicted: なぜならそれはこの先私たちち
# Target:    このためにさまざまな手段を用い
# Predicted: この為めにさまざまな手段を持い
# Target:    彼女はオレがいなくちゃダメなんだ
# Predicted: 彼女は俺がいなくちゃダメなんだ
# Target:    帰宅の途中でにわか雨に遭った
# Predicted: 帰宅の途中でにはカ雨にっった
# Target:    お前達はエジプトの真の息子だ
# Predicted: お前たちはジプトのののの子だだ
# Target:    君を食べるための嘘よかわいい子ね
# Predicted: 君を食べるためのそよかはいいいね
# Target:    まだまだそう簡単に新術とは
# Predicted: まだまだそう簡単ににととは
# Target:    井上もチャドも何も言わねえけど
# Predicted: いのももチャも何ももいわねけど
# Target:    現在そこまでに至っていませんが
# Predicted: 現在そこまでに至たてていませんが
# Target:    少し深く掘り下げるよ伝えてくれ
# Predicted: 少し深く掘り下げるよ伝えてれれ
# Target:    いま貴女と外へ出れば疑われる
# Predicted: 今貴女と外へでれば奪われる
# Target:    彼女はその教師を訪問した
# Predicted: 彼女はその教師をを問した
# Target:    私を理解する為にまず君は
# Predicted: 私を理解するたににま君君は
# Target:    昨年は輸入が輸出を超えた
# Predicted: 昨年は輸入が輸出を越えた
# Target:    知っていることと実行は別物だ
# Predicted: 知っていることと実行は別物のだ
# Target:    彼らに由来する文化に属してる
# Predicted: 彼らに優来する文にに属ててる
# Target:    それならヒメコいい情報があるぞ
# Predicted: それならヒメこいい情報があるぞ
# Target:    メディアがそのような形態の会話を
# Predicted: メディアがそのううな携体の会話を
# Target:    ドラッグの売人をしていたようです
# Predicted: ドラッグの売人をししいいよよです
# Target:    学習手段として利用します
# Predicted: 学習手段として利用します
# Target:    私はこの手のことにはさっぱりだ
# Predicted: 私はこの手のことには去っぱり
# Target:    私達が気づくように仕向けます
# Predicted: 私たちがづくようににけけす
# Target:    証明書の失効日を変更
# Predicted: 証明初の失光費をを更更
# Target:    私のおじいちゃんも下島だよ
# Predicted: 私のおじちゃんもももももだよ
# Target:    なんだかすげぇ所に来ちまった感じ
# Predicted: 何んかすととここちにちちまったじ
# Target:    システムと全く同じ手法です
# Predicted: システムと全く同じ主でです
# Target:    ねえチョウ君みんなをビビらせてるよ
# Predicted: ねえちょうくんんんなをびびらててよ
# Target:    サイレンだ以前は歓迎した音だ
# Predicted: サイレン大以前ははししただだ
# Target:    子供にこれパパがつくったんだぜって
# Predicted: 子供にこれパパが作ったんだだって
# Target:    よく激しい疲労感に襲われます
# Predicted: よく激しい広ににに襲われます
# Target:    わたしたちも応援に行けませんかね
# Predicted: わたしたちも上上にけままんんねね
# Target:    すべての映像を今すぐ出しなさい
# Predicted: すべての像像をすすぐ出なさいい
# Target:    だが基本的に持久力不足
# Predicted: だが基本的に自給力不足
# Target:    陸軍大臣阿南は陛下に乞うた
# Predicted: 陸軍大事な何は平下に効こた
# Target:    僕たちは叔父の家に泊まっています
# Predicted: 僕たち父叔父の家に泊っっいいます
# Target:    レッドレンジャーのみんなさあいこうか
# Predicted: レッドレンジャーのみんなさあ行こうか
# Target:    しかも細部に注意をはらうことは
# Predicted: しかも再部に注意払払うここは
# Target:    だがその話を心に留めておいて
# Predicted: だがその話を心に止めておいて
# Target:    お前らがこれを聞いてることを願う
# Predicted: お前らがこれを聞いてることを願う
# Target:    おいしいチャーターの仕事が入った
# Predicted: おいしいチャーターの仕事が入った
# Target:    彼女が死んだと言う知らせはうそだ
# Predicted: 彼女が死んだとい知知らせはだだ
# Target:    警察に喋ったこと謝るから
# Predicted: 警察に喋ゃべっこと謝るるら
# Target:    帰って睡眠をよく取ってください
# Predicted: 帰って睡眠をよくとって下ささい
# Target:    私を産まなければ生きていられた
# Predicted: 私を生まななけば生きていらたた
# Target:    救えるのに世界は気付かぬままです
# Predicted: 救くるの世世界界は付かぬままです
# Target:    軍需産業の為にやったのか
# Predicted: 軍授産業のためにやったかか
# Target:    彼を犯罪者と呼んではいけない
# Predicted: 彼を犯罪者と呼んででいけない
# Target:    クレイプールと彼のドライブを渡せ
# Predicted: クレイプールと彼のドララブブ渡渡せ
# Target:    領主書にはジョセフロザレスの
# Predicted: 両主所には女セフロロザスス
# Target:    この成果をどうやって次のレベルに
# Predicted: この成果をどうやって次次のベルルに
# Target:    自分の才能に合った望みを持て
# Predicted: 自分の才能に会った望みみ持て
# Target:    ポロニウムを摂取してきた先生
# Predicted: ポロニームを接手してきた先生
# Target:    チンピラを探す時ベテランを探す
# Predicted: チンピラを探すときベララン探探す
# Target:    おばさんがどこに行こうが心配ない
# Predicted: 叔母さんがどこに行こうが心配ない
# Target:    彼女はここに来て姿を消したの
# Predicted: 彼女はここに来て姿を消したの
# Target:    私の知ってる誰かとは違って
# Predicted: 私の知ってる誰かとは違って
# Target:    私たちは平和に暮らしています
# Predicted: 私たは平平に暮暮らてていす
# Target:    シャンパン飲みすぎてコイン拾ってた
# Predicted: シャンパンのみぎぎてこイン拾ってたた
# Target:    彼女は先導車のメイドだった
# Predicted: 彼女は戦動ののメイドだった
# Target:    十分な額がたまるまではダメだ
# Predicted: 十分なくがるるででは駄だ
# Target:    最終的にはこれを使いました
# Predicted: 再終的にはこれを使いました
#
# Validation
# Target:    甲の損は乙の得
# Predicted: コーのソンはおのの得
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン不常しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いていけます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あらけずりな味がする
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 年所からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早く野郎う
# Target:    己の真価を見せよ
# Predicted: 己の進化化見せよよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大週へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたなヘささ
# Target:    えぇマキャリスターです
# Predicted: エマキャリススーーすャ
# Target:    レース用の箒だよ
# Predicted: レース用ののだだよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技からせせろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜ぞを見つつ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアト呼呼せない
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き止めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念なことだ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないでください
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数まなそそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: なだそそさサバイザザー
# Target:    いい人生を送れよ
# Predicted: いい人生を遅れよ
# Target:    声も変える必要が
# Predicted: 声も帰え必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空らだ
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: チェコフはアプできるかか
# Target:    いやお前には出来ない
# Predicted: いやお前には出きない
# Target:    捨てられん大好きだろ
# Predicted: 捨てらレン大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外校
# Target:    ここまでやってこられた
# Predicted: ここまでやってこられた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今げななのよ
# Target:    この機械は価値がない
# Predicted: この機会は価値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 5/20: Learning rate @ 9.70e-05
# 3125/3125 [==============================] - 1027s 328ms/step - loss: 0.7964 - cer: 0.1513 - val_loss: 0.5412 - val_cer: 0.1134
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    王様の料理を最初に試食する
# Predicted: 王様の料理を初初に職すする
# Target:    車が遠い田舎で故障してしまった
# Predicted: 車が遠いい舎で故障してししたた
# Target:    残念だがこの街はそうとは言い切れない
# Predicted: 残念だがこの街はそうとは言いきれれい
# Target:    こんなに白髪がなかった頃の話です
# Predicted: こんなに白発がなかった頃の話です
# Target:    私と共に船に乗り大洋を渡り
# Predicted: 私ととも船に乗りたいををり
# Target:    先回りしていろいろ探らせてもらったよ
# Predicted: 先回割していいろろららててもらたよ
# Target:    あんたの隣にナムギュマンを入れてやるよ
# Predicted: あんたの隣にナムムュマンを入れてやるよ
# Target:    朝田お前にうちの病院を託したい
# Predicted: 朝だお前にうちの病院を託したた
# Target:    それはほとんどいつも一方通行だった
# Predicted: それはほとんどいつも一方通行だった
# Target:    ええまたね近接センサーを始動させるな
# Predicted: ええまたね金切センサーを導動せせる
# Target:    例の証人のことは今調べさせてる
# Predicted: 例の証人のこと今今調べべせてる
# Target:    この語はフランス語から借用したものだ
# Predicted: この後はフランススから釈用したものだ
# Target:    彼女は中学校の校長でした
# Predicted: 彼女は中学校の校校しした
# Target:    授業料の補助金が交付された
# Predicted: 授業料の補女金がが行された
# Target:    そしてこの都市全体の計画プロセスは
# Predicted: そしてこの都自然体の計画プロセスは
# Target:    私はそれらのどちらも気に入りません
# Predicted: 私はそれらのどちらも気に入りません
# Target:    そもそも小脳梗塞は病気ですよ
# Predicted: そもそも小の高速は病気ですよ
# Target:    おれはすぐにここにきて警察を呼んだんだ
# Predicted: 俺はすぐにここに来て警察を呼んだんだ
# Target:    オーグメントがオーグメントを導くべきだ
# Predicted: オォグメトトがオーメトををくくきだ
# Target:    おまえが俺のために働くはずだったんだ
# Predicted: お前が俺のため働働くはずだったん
# Target:    君らが太刀打ち出来る様な相手では無い
# Predicted: 君らが立ちちちききるよう相相手ではな
# Target:    オレはこの施設のどこで寝るべきでしょうか
# Predicted: 俺はこのの施ののここでるるきでしょうか
# Target:    上出来だ顔がほとんど焼けてるわりには
# Predicted: 上出来だ顔ががどんどけけてるわにに
# Target:    お世話になりました稼いだら先生の絵を
# Predicted: お世話になりました火星だら先生の絵を
# Target:    彼女が居なければ奴を捕まえられない
# Predicted: 彼女がいなければ奴を捕まえらられい
# Target:    いやだってお前が余計なこと言うからだよ
# Predicted: いやだってお前が余計なこと言うからだ
# Target:    彼は真実を知っているように思われる
# Predicted: 彼は真実を知っているように思われる
# Target:    藤子ちゃんとっくに誰かの一番じゃん
# Predicted: 藤じこちゃんとくくに誰かの一番じゃ
# Target:    コーヒーないじゃないかしょうがねぇなレジー
# Predicted: コーヒーないじゃないかしょうがねナレジーー
# Target:    商談会ですよ今日が最終日で
# Predicted: 小談階ですす今日が最でで
# Target:    後で検索かけて絶対フォローしとくよ
# Predicted: 後で検検査かてて絶大おろししとよ
# Target:    あなたに会ってから私は吐き続けたわ
# Predicted: あなたに会ってから私は吐き続けたわ
# Target:    デザインのインスピレーションにはなりません
# Predicted: デザインのインスピレーションにはなりません
# Target:    私ゲレンデがとけるほどの恋がしたい
# Predicted: 私ゲレンでがとけるほどのががしたい
# Target:    手配して監視カメラで探すからよろしく
# Predicted: 手配して監視カメラで探すからよしし
# Target:    誰でもビビると思ってんなよなめんなコラ
# Predicted: 誰でもビビルと思ってんなななめんんココ
# Target:    私にも希望が必要なんだピーター
# Predicted: 私にも希望が必要なんだピータ
# Target:    日曜日にエミと私はテニスをします
# Predicted: 日曜日にエとと私はテニスししま
# Target:    フェイスブックへの大量の書き込みでした
# Predicted: フェイスブックへの大量のきき込みでした
# Target:    彼らがベレンソン氏と並行になった時
# Predicted: 彼らがベレンソン氏市平行になったと
# Target:    出港以来彼はずっと船首にいる
# Predicted: 出行以来彼はっと戦戦手にいる
# Target:    リバプールとチェルシーの親善試合なんだ
# Predicted: リバプールとシェルシーの進然試合ななだ
# Target:    あまり気持ちのいいものではありませんでした
# Predicted: あまり気持ちのいいものではありませんでした
# Target:    私はこの町に住み仕事をしています
# Predicted: 私はこの街に住仕事をしてていま
# Target:    全ての責任を負う覚悟は出来ています
# Predicted: 全べの責責任をおくくはできていいす
# Target:    見た瞬間驚き磁石の性質への
# Predicted: 見た瞬間の泥記自ののの室へ
# Target:    地球全体を火の海にしてできました
# Predicted: 地球全体を日の生にしてできました
# Target:    断るそれがあんたに課せられた運命だ
# Predicted: 断るるそれああんたにせせれた運命命
# Target:    道の先に病院があって裏庭では
# Predicted: 道ちの先病院院あっててににはは
# Target:    いや万が一見えてたら引くかなぁと思って
# Predicted: いやマンが一見てたらひくかなと思って
# Target:    なあいったん戻ってクルマを探せないかな
# Predicted: なあいったん戻って車を探探せなかな
# Target:    あたしには大事な友達が何人もいて
# Predicted: あたしには大事な友達何何人もいて
# Target:    チャーリーは夫人とビーチで楽しんでるさ
# Predicted: チャーリーは夫人とビーで楽しんんでる
# Target:    彼女がしたのは寒い乾燥した夜に
# Predicted: 彼女がしたのは寒い観想したよに
# Target:    俺がリーダーになってから歯向ってくるが
# Predicted: 俺がリーダーになってからハ向かってくるが
# Target:    ああ貴方が気にするとは思いませんでした
# Predicted: あああなたが気にするとは思いませんでした
# Target:    あら上条君退院なさったんですの
# Predicted: あら上条訓員員なさったんででの
# Target:    何もしてないよ今出て行くところだったよ
# Predicted: 何もしてないよ今まてていくところだたよ
# Target:    警官になりたいと思ったことはないんだ
# Predicted: 警官になりたいと思ったことはないんだ
# Target:    いいえ私は純血種アライグマだ
# Predicted: いいえ私は受ュアアラララグだだ
# Target:    ただの話題にしているだけだと思いました
# Predicted: ただの話台にしているだけだと思いました
# Target:    しかし同時に娘がレズビアンだったため
# Predicted: しかし同時に娘がレずビアンだっっため
# Target:    でもあなたはおそらく食べないのね不死だから
# Predicted: でもあなたは恐そく食食ななのね不死だから
# Target:    信じてくれるならもっとゲームを楽しめる
# Predicted: 信じてくれるならもっとゲームを楽しめる
#
# Validation
# Target:    甲の損は乙の得
# Predicted: コののソンはおののと
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン夫上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いていけます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あらずながががる
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 年所からの日日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早くやろう
# Target:    己の真価を見せよ
# Predicted: 己の進化を見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大衆へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたな変ささん
# Target:    えぇマキャリスターです
# Predicted: えェマャャリスターですー
# Target:    レース用の箒だよ
# Predicted: レース用のの気だよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技からせせろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜ぞを見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アッチュュと呼ばばなな
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き留めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念なことだ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないで下ださい
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数枚なそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそのさンバイザザー
# Target:    いい人生を送れよ
# Predicted: いい人生を遅れよ
# Target:    声も変える必要が
# Predicted: 声も帰る必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空と第
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: シェコフははプできるかる
# Target:    いやお前には出来ない
# Predicted: いやお前には出きない
# Target:    捨てられん大好きだろ
# Predicted: 捨てられん大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外校
# Target:    ここまでやってこられた
# Predicted: ここまでやって来られた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今ゲイなのよ
# Target:    この機械は価値がない
# Predicted: この機会は勝値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 6/20: Learning rate @ 9.33e-05
# 3125/3125 [==============================] - 1004s 321ms/step - loss: 0.4715 - cer: 0.1373 - val_loss: 0.5483 - val_cer: 0.1046
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    ああそれは援助を求める叫びなんだ
# Predicted: ああそれは援助を求める叫びなんだ
# Target:    実際去年の夏に科学者たちが
# Predicted: 実際去年の夏に科学者たちがが
# Target:    飛んでいる火花から察するとそのはずよ
# Predicted: 飛んでいる火から察するとそそのはず
# Target:    昨夜雄ジカの頭が盗難にあったと
# Predicted: 昨夜叔次家の頭頭当難あ会たたと
# Target:    劇場には多くの聴衆がいた
# Predicted: 激場には多くの聴衆がた
# Target:    交通事故に遭った場合よりも素早く
# Predicted: 交通事故にあった場合よりも素早薬
# Target:    なんであんたみたいなのは存在すんのよ
# Predicted: 何であんたたたいなのは存存すんのよ
# Target:    君がパリへ行くというのは本当ですか
# Predicted: 君がパリへークというのは本当ですか
# Target:    それで情報が細胞内に伝わり
# Predicted: それで情報が細胞内に伝わりり
# Target:    私達はみな果たすべき仕事がある
# Predicted: 私たちは見果たべべき仕事ががる
# Target:    シミは死んだんだ現実を受け入れるんだ
# Predicted: 市みは死んだんだ現実を受け入れるんだ
# Target:    人形を使って表現しています
# Predicted: 人形を使って表現してまます
# Target:    その二人の子供は同じ年齢だった
# Predicted: その二人の子供は同じ年齢だった
# Target:    費やしすぎていると主張しています
# Predicted: 費やしすぎぎいるる主主していますす
# Target:    黒曲が今でも町とつながりを持ち
# Predicted: 黒局が今でも町とつ繋りり持ちち
# Target:    ごめんね何かちょっとおなか減っちゃって
# Predicted: ごめんね何かちょょとおおか減ちちっって
# Target:    化石燃料由来の化学肥料を
# Predicted: 化石燃料由来の科学学学を
# Target:    期待してくれぼくの踊りは宙を舞う
# Predicted: 期待してくれ僕の踊りは中ををう
# Target:    彼はベンについていくらかの知識を得た
# Predicted: 彼はベンについていららかの知識を得た
# Target:    なんでお前はスカウトを統率できない
# Predicted: 何んで前前スカカーをを率でききない
# Target:    担当判事はまだ決まっておりませんが
# Predicted: 担当判事はまだ決まっておりませんが
# Target:    第一の原則はありのままであること
# Predicted: 第一の幻測はありのままであること
# Target:    これは役に立つ本でおまけに高くない
# Predicted: これは役に立つ本でお負けににくくない
# Target:    チームを団結する方法は二つだけ
# Predicted: チームを断決する方法は二つだけ
# Target:    彼女が作る迷路が再現できるな
# Predicted: 彼女が作る名路が再現でできるな
# Target:    今度の君の査定覚悟しておくように
# Predicted: 今度の君の作定悟誤しておくように
# Target:    君の意見にも誰も興味を持たない
# Predicted: 君の意見にも誰も興味を持たない
# Target:    ケーキを食べに来た訳ではありませんから
# Predicted: ケーキを食べに来たわけではありませんから
# Target:    すぐに出発したくてうずうずしている
# Predicted: すぐに出発したくてうズーズしている
# Target:    それはまさに彼女に対する侮辱だ
# Predicted: それはまさに彼女に対する侮辱だ
# Target:    お互いに歩み寄ってはいかがでしょうか
# Predicted: お互いに歩ゆみよっはいいががしょょうか
# Target:    ラストは俺の意見で名誉勲章を
# Predicted: ラストは俺の意見で名誉勲章を
# Target:    これ以上私を怒らせない事ね
# Predicted: これ以上私を怒らせなことと
# Target:    彼女は私に会うためにここにきた
# Predicted: 彼女は私に会うたににここに来た
# Target:    彼女なしで生きたくないが死ねもしない
# Predicted: 彼女なしで行きたくないが死ねもしない
# Target:    元気を取り戻して人生にたちむかえ
# Predicted: 元気を取り戻して人生に立ち向かえ
# Target:    真面目な話悪ふざけはすべきじゃない
# Predicted: 真面めな話悪ふざざはすべきじゃない
# Target:    脳のこの部分は静まり返っています
# Predicted: 脳のこの部分は沈まり帰っています
# Target:    私小さいころ背が高いのが嫌で
# Predicted: 私小ささ殺殺がが高い外家家で
# Target:    急に左目に激しい痛みを感じ
# Predicted: 急に左目ににしい遺みを感じ
# Target:    空調を制御する人が居ないとき
# Predicted: 空長を制御する人がいないと
# Target:    私もスラッピージョー食べたかったの
# Predicted: 私もスラッピージョー食べたっったの
# Target:    寄生虫は小さいものと決まっており
# Predicted: 寄生中は小さいものと決ってており
# Target:    新生代は全ての動きが速いです
# Predicted: 新聖代は全べの動動ががいですす
# Target:    ランダムプレイリストを上書きできません
# Predicted: ランダムプレーリストを上書きききません
# Target:    この惑星は重量と大きさから
# Predicted: この惑星は重領と大きさから
# Target:    しばらく安静にしてればよくなりますよ
# Predicted: しばらく安ににしてれよ良くなりますよ
# Target:    売人を捕まえようとしたの建物で
# Predicted: 売人を捕まえようとしのの建物物
# Target:    謙虚さを教えてくれたチンパンジーが
# Predicted: 謙虚さを教えてくれたチンパンジーが
# Target:    ギデオンはリパーの正体を知っている
# Predicted: ギデオンはリパーの正待を知っている
# Target:    今すぐには数にいれないでくれハロルド
# Predicted: 今すぐには数に入れないでくれハロルド
# Target:    新見君イズモ計画は破棄されたのだよ
# Predicted: ニーミクズ計計計は吐きされただだよ
# Target:    ウィンターズ刑事ねあたしが連絡するわ
# Predicted: ウィンターズ刑事アたたしがが絡するわわ
# Target:    どのドアを開けるべきか彼女は迷った
# Predicted: どのドアを開けるべきか彼女は迷った
# Target:    これはシスコ製だ君でも大丈夫だ
# Predicted: これはシスコ性だ君でも大丈夫だ
# Target:    実際彼女は君にとても敵してる
# Predicted: 実際彼女は君にとても的ししてる
# Target:    おろせって言われたら寂しくもなるでしょ
# Predicted: 下ろせって言われたら寂しももなるでしょ
# Target:    物語は意外な場所に現れます
# Predicted: 物語は以外な場所に現れます
# Target:    そして彼は信じ続けなければならない
# Predicted: そして彼は信じ続けなければならない
# Target:    真剣に新しいピザ屋を探すべきよ
# Predicted: 神剣に新しいピザ屋を探すべきよ
# Target:    こんなとこ座ったらスカート汚れちゃう
# Predicted: こんなと壊座ったらカカーとれれちゃう
# Target:    やはりこの奥が発生源のようですね
# Predicted: やハりこの奥が発生源のよでですね
# Target:    なぜそんなに神経質になってるんだい
# Predicted: 何故そんなに神経室になってるんだい
# Target:    彼は強暴な独裁者だったんだ
# Predicted: 彼は強望な毒最者だったんだ
#
# Validation
# Target:    甲の損は乙の得
# Predicted: 公のソンはおのの得
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン夫上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いて行けます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あらずりりががが
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 燃所からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早く野郎う
# Target:    己の真価を見せよ
# Predicted: 己の進化を見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大衆へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたな変ささ
# Target:    えぇマキャリスターです
# Predicted: えママキキリスターですす
# Target:    レース用の箒だよ
# Predicted: レース用の方気だよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技から撃せろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜空を見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアと呼呼せない
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き留めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念なことだ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないで下ださ
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数舞いそそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここに居るべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそのサンバイザザ
# Target:    いい人生を送れよ
# Predicted: いい人生を遅れよ
# Target:    声も変える必要が
# Predicted: 声も帰え必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空と一
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: チェコフはアプ出来るかる
# Target:    いやお前には出来ない
# Predicted: いやお前には出来ない
# Target:    捨てられん大好きだろ
# Predicted: 捨てらレン大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外校
# Target:    ここまでやってこられた
# Predicted: ここまでやって来られた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今ゲーなのよ
# Target:    この機械は価値がない
# Predicted: この機械は価値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 7/20: Learning rate @ 8.83e-05
# 3125/3125 [==============================] - 1047s 335ms/step - loss: 0.7408 - cer: 0.1255 - val_loss: 0.5132 - val_cer: 0.1024
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    彼は私を見るとすぐに青ざめて逃げ出した
# Predicted: 彼は私を見るとすぐに青ざめて逃げげしたた
# Target:    ウィザードを見つけて下さいリチャードコンラッドを
# Predicted: ウィザードを見見けけくだいリリャードココラッドをを
# Target:    ティリオンが有罪であれば相応の罰を受ける
# Predicted: イィリンが有罪であれば相相の罰を受けるる
# Target:    大気中の二酸化炭素の排出量を
# Predicted: 大気中の二酸化炭素の排出量を
# Target:    だが他を殺してもいいがミショーンは生け捕りに
# Predicted: だが他を殺してもいいがミショーンはいけどりに
# Target:    まだ見て回んのかよはいまだまだ見て回りますよ
# Predicted: まだ見て回んのかかはいだだだだて回回ますよ
# Target:    なんか変なビジョンが頭に流れ込んでくるよ
# Predicted: 何か変なビジョンが頭頭流れれ込んでるよ
# Target:    銀行からの融資否決通知略奪された
# Predicted: 銀行からの融子日欠通治着奪さされた
# Target:    茎状の体から羽毛状の先端まで
# Predicted: 空上上の体ららううのののままで
# Target:    私は父を白日のもとにさらしたのでした
# Predicted: 私は父を白日のもににらしたののしした
# Target:    これから先は常に見張られてると思うべきだな
# Predicted: これから先は常に見張られてると思うべきだな
# Target:    いいか伝えてくれもっと働け心配は要らん
# Predicted: 言いか伝えてくれもっと働け心配はいらん
# Target:    ねえ奈津美ちゃんの旦那って確かオーケストラの
# Predicted: ねえ奈ツ美ちゃんの旦なてててかおけススラの
# Target:    陪審裁判のアドバイザーたちが控えていて
# Predicted: 陪審裁判のアドドイザータ立が控ええいてて
# Target:    これが今日ご覧いただく最後のプロジェクトです
# Predicted: これが今日ごらににくく最後のプロジェクトです
# Target:    フンそこのチキン野郎にそんなかい性はねえよ
# Predicted: フンそこのチキ野野ににそんな会ははねえ
# Target:    なあ教えてくれよ他に誰が居るって言うんだい
# Predicted: なあ教えてくれよ他に誰がいるって言うんだい
# Target:    だから時間はそうかからないでしょう飲みましょう
# Predicted: だから時間はそうかからないでしょう飲みましょう
# Target:    彼がこないだ私が話していた少年だ
# Predicted: 彼がこないだ私が話していた少年だ
# Target:    私の提案を承認していただけますか
# Predicted: 私の提案を承認認ていただけますか
# Target:    時間を逆戻りして届けてくれるんですから
# Predicted: 時間を逆戻りして届けくくるるんですから
# Target:    この美しい賞を獲得したと感じてます
# Predicted: この美しい装を獲獲ししと感感てまま
# Target:    彼の援助は非常に貴重なものであった
# Predicted: 彼の援助は非常に貴重なものであった
# Target:    あなたには効かないということも十分あり得ます
# Predicted: あなたには聞かないということも十分なり得ます
# Target:    今日はみなさんに転校生を紹介します
# Predicted: 今日は皆さんに天校校を紹介します
# Target:    皆様は元ストリッパーだって仰ってます
# Predicted: 皆様はもトトトリッパだっておっしゃっっます
# Target:    ちょっと問題が起きて失神してるが彼です
# Predicted: ちょっと問題が起きて失心してるが彼です
# Target:    私の人生はどうなっていたかなと思うの
# Predicted: 私の人生はどうなっていたかなと思うの
# Target:    カナダアイルランドスウェーデンはもう言いましたが
# Predicted: カナダアイルランドスへェイデンはも言言ままたががた
# Target:    私にあまり多くの期待をしないでください
# Predicted: 私にあまり多くの期待をしないでください
# Target:    最初にがん感受性遺伝子を発見した
# Predicted: 最初にがん受受遺電子を発発しした
# Target:    律っちゃんきっとあいつのことを考えてるんだ
# Predicted: 正しゃゃんきっとあいののとををえてるんん
# Target:    何も言うことはねえよ自分のケツは自分で拭く
# Predicted: 何も言うことはねえよ自分分のツツは自でで
# Target:    これを静水力学的骨格と呼んでいます
# Predicted: これを精推陸学的国格格呼んでいいす
# Target:    彼女は取引してる筈だ奴から血の為に
# Predicted: 彼女は取引してるはずだ奴つかちのたたにに
# Target:    よし地元の大学にいくつか連絡してみよう
# Predicted: よし地元の大学にいくつか連絡してみよう
# Target:    刑事の安月給で飲めるような店じゃない
# Predicted: 刑事の暗月求で飲めるような店ゃゃない
# Target:    中でお座りくださいイギリス人を連れて来ます
# Predicted: 中でお座りくださいいギリス人を連れてきます
# Target:    ワクチンにアレルギー反応を起こしたようですね
# Predicted: ワクチンにアレルギー反応を起こしたようですね
# Target:    あの男を殺した人物を説明出来ますか
# Predicted: あの男を殺した人物を説明できますか
# Target:    本の中のどのエッセイとも関連していません
# Predicted: ほん中中どのの生とも関関していませんん
# Target:    父さんはこういう男だ変わりたいと思ったが
# Predicted: 父さんはこういう男だ変わりたととったが
# Target:    皆さんは本の電子化に貢献しているのです
# Predicted: 皆さんはほのの子子かに貢献しているのです
# Target:    信じてもらえないだろうけど俺は嘘を言わない
# Predicted: 信じてもらえないだろうけど俺は嘘を言わないい
# Target:    他地区の病院から来る臨時職員もいる
# Predicted: 他ち区病病院から来るン食食員もい
# Target:    他の国のやり方から学ぶ事もありそうです
# Predicted: 他の国のやり方から学ぶこともありそうです
# Target:    研究室で陰茎パズルは構築できない
# Predicted: 研究室で院形パズルは構築築きない
# Target:    原子と衝突しますがこの衝突によって
# Predicted: 原始と衝突しますがこの衝突よよって
# Target:    上も私も待たされるのはあまり好きじゃない
# Predicted: 上も私も待たれるるのああまり好きじなない
# Target:    未完成のガリレオテゾロ完成させなくちゃね
# Predicted: 未完性のがリレおてぞゾ完成させなくちゃね
# Target:    アタシの勘じゃ何か知ってる様子ではあるんだ
# Predicted: あたしの患者何か知ってる様様ではあるんだ
# Target:    自然エネルギーのコントロールをする修業じゃ
# Predicted: シ然ネネルギーのコントロールをるる修授じ
# Target:    賞品とプライドを掛けたレースが始まります
# Predicted: 商品とプライををかけたレースが始まります
# Target:    そんなに早く成長して欲しくはないってこと
# Predicted: そんなに早く成長して欲しくはないってこと
# Target:    最初はマリッジブルーなのかと思っていたけど
# Predicted: 最初はマリッジブルーなのかと思っていたけど
# Target:    チャンスがあった時グレトゲンを殺せばよかった
# Predicted: チャンスがあった時ぐレトゲンを殺せばばかった
# Target:    奴らは恐怖に怯えた少年を連れ去った
# Predicted: 奴らは恐怖ににええ少年を連連去去った
# Target:    彼らにアンソニーの責任を取らせると話した
# Predicted: 彼らにアンソニーの責任を取らせると話した
# Target:    彼女にこの称号と場所を与えることで
# Predicted: 彼女にこの照合と場所を与えることで
# Target:    あなたの目の前でフリークの出産ショーだよ
# Predicted: あなたの目の前でフリークの出産症だよ
# Target:    分かった今日真城君にメールで相談してみる
# Predicted: わかった今日君君にメーでで相談してみる
# Target:    パンバニーシャはまるで人間の母親のように
# Predicted: パンバニー者ははるる人人間母母のよううに
# Target:    第一に操作が非常に難しかったのです
# Predicted: 第一に捜査が非常に難しかったのです
# Target:    私はフランスのストラスブールで生まれました
# Predicted: 私はフランススストラスブールで生ままました
#
# Validation
# Target:    甲の損は乙の得
# Predicted: 公のソソはおつの得
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン夫上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いていけます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: 荒ずりりががる
# Target:    ほんとうにおいしいです
# Predicted: 本当にお味しいです
# Target:    年初からの日数
# Predicted: 年所からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早くやろう
# Target:    己の真価を見せよ
# Predicted: 己の進化を見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大衆へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたな変ささ
# Target:    えぇマキャリスターです
# Predicted: ジェマキキリスターですで
# Target:    レース用の箒だよ
# Predicted: レース用のの気だよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技かららせろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜空を見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアと呼呼ばなな
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き留めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念なことだ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すででも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないでください
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数枚なそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそのサンバイザザー
# Target:    いい人生を送れよ
# Predicted: いい人生を遅れよ
# Target:    声も変える必要が
# Predicted: 声も帰る必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空ら大
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: チェコフワープできるかか
# Target:    いやお前には出来ない
# Predicted: いやお前にはできない
# Target:    捨てられん大好きだろ
# Predicted: 捨てられん大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外校
# Target:    ここまでやってこられた
# Predicted: ここまでやって来られた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今ゲーなのよ
# Target:    この機械は価値がない
# Predicted: この機会は価値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 8/20: Learning rate @ 8.21e-05
# 3125/3125 [==============================] - 998s 319ms/step - loss: 0.6292 - cer: 0.1170 - val_loss: 0.5625 - val_cer: 0.0996
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    分ってるよでもアレかとクモアンタも怖いんだろ
# Predicted: 分かってるよでもあれかともあんんも怖いんんだろ
# Target:    黒い服を着た男の人なんていなかったって
# Predicted: 黒い服を着た男の人なんていなかったって
# Target:    シネストロ最大速度で来るようにとフェンタラが
# Predicted: シネストロ最イ大速ででるよううにとえンンラがが
# Target:    彼らはケイトリンを取り彼らは彼女を撃った
# Predicted: 彼らはケイトリンを取り彼らは彼女を撃った
# Target:    なんとしても夜明け前に奴をムショにぶち込むぞ
# Predicted: 何とししも夜明明けにに奴をム所ににちちちぞぞ
# Target:    銀行のお金の動き光熱費記録が皆無
# Predicted: 銀行のお金の動き好熱日記録が解無
# Target:    秘密を守るためにみんながどれだけ苦労したか
# Predicted: 秘密を守るためにみんながどれだけ苦労したか
# Target:    今日は聖なる祝日だから忙しくなるね
# Predicted: 今日は聖なる宿日だかか忙しくなるね
# Target:    お前が俺を信頼してくれてれば良かったのに
# Predicted: お前が俺を信頼してくれれればよかったのに
# Target:    彼女が正しいというのが私の意見です
# Predicted: 彼女が正しいというのが私の意見です
# Target:    自分が命を狙われていると印象づけた
# Predicted: 自分が命を狙わわていると印印証けけた
# Target:    莫大な資産を持つずるい億万長者か
# Predicted: 莫大な資産をを持るいい億満長じか
# Target:    あなたはラッキーですね私が責任者です
# Predicted: あなたはラッキーですね私が責任者です
# Target:    私の弟が亡くなって何年も経つのに
# Predicted: 私の弟がなくなって何年も持つつに
# Target:    牛で金儲けしたいなら牛を売ればいいだけだ
# Predicted: 牛で金もうけしたいなら牛を売ればいだだけだ
# Target:    フォードをクリックしてみるとそれが中心になり
# Predicted: フォードをクリッククしるるとそそれ中心になり
# Target:    僕はあいつらについて本当に全部話したよ
# Predicted: 僕はあいつらにつつて本当に全部話したよ
# Target:    森山先生が言ってんだから大丈夫だよ
# Predicted: 森山先生が言ってんだから大丈夫夫よ
# Target:    もちろんオレが勝ったらお妙から手を引いてもらう
# Predicted: もちろん俺がががったらおおか手手を引いててらう
# Target:    タマーラ従兄弟のズーシュを覚えているな
# Predicted: タマーラ銃系提のズ手を覚ええているな
# Target:    契約書の空欄に要望を記入してね
# Predicted: 契約書の空欄に要望望記記ししねね
# Target:    キリスト教を理解する時中心にあって
# Predicted: キリスト教を理解解る時中中心にあっ
# Target:    この疑問を解くためそして人がデートをしてから
# Predicted: この疑問を解くためそして人がデートをててから
# Target:    彼らはおしゃべりをしながら遅くまで起きていた
# Predicted: 彼らはお喋ゃりををながら遅くまで起きていた
# Target:    世界中の政府が何十億ドルもかけて
# Predicted: 世界中の政府が何十億くるもかけてて
# Target:    手に入れたのは銃や麻薬のディーラーの巣からだ
# Predicted: 手に入れたのは銃役薬薬フフィラーのススかだ
# Target:    自分の家族のための食べ物を買いに来るのです
# Predicted: 自分の家族のための食べ物を買いに来るのです
# Target:    このようにわれは罪のある者たちを処分する
# Predicted: このように我はは罪のあるるた達ち処処すす
# Target:    今度の映画の完成を阻止したい勢力が
# Predicted: 今度の映画の完性を阻ししたい勢力が
# Target:    押したり髪を引っぱったりする時しか触らないわ
# Predicted: 押したり神を引っぱたりするるとかからななわわ
# Target:    お前は抹消された時間軸のゴミにすぎん
# Predicted: お前は抹生された自時軸のゴゴミに過ぎぎ
# Target:    ただあなたがあまり笑顔を見せないなって思って
# Predicted: ただあなたがあまり笑顔を見せないなって思って
# Target:    夢中になってたのあなたじゃない他の誰かに
# Predicted: 夢中になってたのあなたじゃない他の誰かに
# Target:    本部と相談してそちらに向かわせてもらいます
# Predicted: 本部と相談してそちらに向かかせてもらいます
# Target:    ではご一緒にどうぞ話の続きをしましょう
# Predicted: ではご一緒にどうぞ話ののきをしまししう
# Target:    率直に申し上げますあいつはやめた方がいい
# Predicted: 率直に申し上げげすあいつは辞めた方方いいい
# Target:    アーチーは魂をはぐくむためにここに来たんだ
# Predicted: アーチーは魂を剥くたためここここ来たんだ
# Target:    だから最高のチャンスは走ることだこのように
# Predicted: だから最高のチャンスは走ることだこのように
# Target:    うん彼女はスターリング市にまっすぐ向かってる
# Predicted: うん彼女はスターリングににまっぐぐ向かってる
# Target:    フッ留美さんみたいな女性すてきだと思うけどなぁ
# Predicted: フルみさんみたいな女性素敵敵と思うけどど
# Target:    そのとき僕の仲間達を呼びに行ってくれたのが
# Predicted: その時僕のの仲間ちををびび行ってくれたたが
# Target:    それを補うだけのお金が十分になかった
# Predicted: それを疑うだけのお金が十十分ななかっ
# Target:    少しでも動いたら殺すからな腹を決めました
# Predicted: 少しでも動いたら殺すから腹腹をを決めしし
# Target:    記録によると彼は高校も卒業してない
# Predicted: 記録によると彼は高校も卒業してなな
# Target:    諦めざるを得ませんでしたデモ行進がまるで
# Predicted: あきらるる得得ませんしたたでも信ががまる
# Target:    ロバートは利益のほんの一部しかもらわなかった
# Predicted: ロバートは利益の本の一部しかもらわななった
# Target:    すべてが封印されている技術嘆かわしいね
# Predicted: 全べがが印さされてるる技術なげはわしいね
# Target:    やだやだいや違うお願いですありがとう失礼
# Predicted: やだやだいや違うお願いですありりとう失礼
# Target:    どうか私にあなたの素性を教えてください
# Predicted: どうか私にあなたの素性を教えてください
# Target:    前に酒製造所の会計をしてた時にさ
# Predicted: 前に酒製造所の会計をしてた時ににさ
# Target:    共演したとき練習してきたバージョンが
# Predicted: 教演したとき練習してきたバージンンが
# Target:    君の人生は強制的に生き続けさせる
# Predicted: 君の人生は強制的に生き続けさせる
# Target:    そのための家族や仲間であるべきじゃないですか
# Predicted: そのための家族や仲間であるべきじゃないでです
# Target:    ユリが趣味なのね俺が男だって知ってんだろ
# Predicted: ユュが趣味なのね俺が男だだてっってんだろ
# Target:    ご想像の通り私は再生医学者で
# Predicted: ご想像の通り私は最最医学学で
# Target:    私の交配計画は再開元通りに
# Predicted: 私の後配計画は再加現とりに
# Target:    当時は特に何も期待していなかったようです
# Predicted: 当時は特に何も期待していなかったようです
# Target:    あまり専門的な略語は使わないで欲しい
# Predicted: あまり専門的な略語は使わないで欲しい
# Target:    ブライアンはお母さんに宿題をやってもらう
# Predicted: ブライアンはお母さんに宿題をやってもら
# Target:    君は私の弟だぞうまくいくと思うか
# Predicted: 君は私の弟だぞうまくいくとと思か
# Target:    中にはそれを打ち破る勇気を持つ人もいます
# Predicted: 中にはそれを打ち破る勇気を持つ人もいます
# Target:    来週は新しいゲストを迎える予定です
# Predicted: 来週は新しいゲストを迎迎る予予です
# Target:    彼がみんなとトランプをしているところをみました
# Predicted: 彼がみんなとトランプをしているところを見ました
# Target:    あなたに折り入ってお話したいことがあるのですが
# Predicted: あなたに折り入ってお話したいことがあるのですが
#
# Validation
# Target:    甲の損は乙の得
# Predicted: コのソソンはつのの
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン夫上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いていけます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あら削なり味するる
# Target:    ほんとうにおいしいです
# Predicted: 本当にお味しいです
# Target:    年初からの日数
# Predicted: 年所からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早くやろう
# Target:    己の真価を見せよ
# Predicted: 己の進化を見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大衆へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたな変さんん
# Target:    えぇマキャリスターです
# Predicted: ジェマキャリリターですス
# Target:    レース用の箒だよ
# Predicted: レイス用の方気だよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技から失せろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜空を見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアと呼ばせない
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き留めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念な事と
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないでください
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数枚なそそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそのサンバイザー
# Target:    いい人生を送れよ
# Predicted: いい人生を遅れよ
# Target:    声も変える必要が
# Predicted: 声も帰る必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空ら第
# Target:    俺がそういったからだ
# Predicted: 俺がそううったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: チェコフはープで来るかる
# Target:    いやお前には出来ない
# Predicted: いやお前にはできない
# Target:    捨てられん大好きだろ
# Predicted: 捨てラれン大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外校
# Target:    ここまでやってこられた
# Predicted: ここまでやって来られた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今ゲえなのよ
# Target:    この機械は価値がない
# Predicted: この機械は価値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 9/20: Learning rate @ 7.50e-05
# 3125/3125 [==============================] - 1001s 320ms/step - loss: 0.2896 - cer: 0.1075 - val_loss: 0.5722 - val_cer: 0.1011
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    本気なんだが
# Predicted: 本気なんだが
# Target:    いいコンビだな
# Predicted: いいコンビだな
# Target:    彼女を撃て
# Predicted: 彼女を撃て
# Target:    せっかくだけど
# Predicted: せっかくだけど
# Target:    どうなってんの
# Predicted: どうなってんの
# Target:    ロンドンで買い
# Predicted: ロンドンでかい
# Target:    彼を救える
# Predicted: 彼を救える
# Target:    オーマイゴッド
# Predicted: オーマイゴッド
# Target:    看護婦どうだ
# Predicted: 看護婦動うだ
# Target:    家に帰ろう
# Predicted: 家に帰ろう
# Target:    いただきまーす
# Predicted: いただきまース
# Target:    バイオリンです
# Predicted: バイオリンです
# Target:    セイバー済まん
# Predicted: セイバースマン
# Target:    みんなよく聞け
# Predicted: みんなよく聞け
# Target:    またにしてくれ
# Predicted: またにしてくれ
# Target:    稼ぎはどうだ
# Predicted: 稼ぎはどうだ
# Target:    どうしてここに
# Predicted: どうしてここに
# Target:    続きを読んで
# Predicted: 続きを読んで
# Target:    ああ始めよう
# Predicted: ああ始めよう
# Target:    かなり多作だ
# Predicted: かなり策策だ
# Target:    あっ帰らなきゃ
# Predicted: あ帰らなきゃ
# Target:    ホテルだ行こう
# Predicted: ホテル大行
# Target:    痛いよ兄貴
# Predicted: 痛いよ兄貴ニキ
# Target:    今のネタバレ
# Predicted: 今のねタバれ
# Target:    カメラメディア
# Predicted: カメラメディアカ
# Target:    フェンスへ向え
# Predicted: フンンスへ迎え
# Target:    そっちを支えろ
# Predicted: そっちを支えろ
# Target:    ご近所だし
# Predicted: ご近所だし
# Target:    間違ってない
# Predicted: 間違ってない
# Target:    もらっときなよ
# Predicted: もらっときなよ
# Target:    でも言わないと
# Predicted: でも言わないと
# Target:    気分はいいか
# Predicted: 気分はいいか
# Target:    一度別れて
# Predicted: 一度別れれて
# Target:    君が先だろ
# Predicted: 君が先だろ
# Target:    出て来やがった
# Predicted: 出てきやがった
# Target:    開拓時代
# Predicted: 解拓時代
# Target:    女を入れろ
# Predicted: 女をいれろ
# Target:    でもあれ以来
# Predicted: でもあれ以来
# Target:    実は朝方
# Predicted: 実は朝がた
# Target:    ジェイカーリよ
# Predicted: ええイカーリよえ
# Target:    お前がボスか
# Predicted: お前がボスか
# Target:    ふざけた真似を
# Predicted: ふざけた真をを
# Target:    保安処置だ
# Predicted: 保安処置だ
# Target:    話しがあるの
# Predicted: 話があるの
# Target:    お元気ですか
# Predicted: お元気ですか
# Target:    付帯事項か
# Predicted: 二い事項か
# Target:    言葉を言って
# Predicted: 言葉を言って
# Target:    後ろに下がれ
# Predicted: 後ろににがれ
# Target:    分かっているな
# Predicted: 分かっているな
# Target:    うんそうだよね
# Predicted: うんそうだよね
# Target:    ポートランドの
# Predicted: ポートランドの
# Target:    シートベルトを
# Predicted: シートベルトを
# Target:    夫のレジよ
# Predicted: 夫のレレよ
# Target:    信じられない
# Predicted: 信じられない
# Target:    無事で良かった
# Predicted: 無事でよかった
# Target:    サンディー進め
# Predicted: サンディー進
# Target:    どんなゲームだ
# Predicted: どんなゲームだ
# Target:    ダメダメまさか
# Predicted: だメダメまさか
# Target:    ギャンブルええ
# Predicted: ギャンブルえー
# Target:    待ってこれかな
# Predicted: 待ってこれかな
# Target:    弟なのよ
# Predicted: 弟なのよ
# Target:    全て過ぎ去る
# Predicted: すてすぎ去る
# Target:    殺すのですか
# Predicted: 殺すのですか
# Target:    君の成果だ
# Predicted: 君の成果だ
#
# Validation
# Target:    甲の損は乙の得
# Predicted: 公のソソンおのの得
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン夫上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いていけます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: 荒削りな味がるる
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 年所からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早くやろ
# Target:    己の真価を見せよ
# Predicted: 己の進化を見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大衆へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたなヘェさん
# Target:    えぇマキャリスターです
# Predicted: エマキャリスターですす
# Target:    レース用の箒だよ
# Predicted: レイス用のの棄だよ
# Target:    もう一回いってみて
# Predicted: もう一回行ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技から失せろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜空を見つめ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアと呼ばせない
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き留めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念な事と
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないでください
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 十数枚いなそかか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそのサンバイザーー
# Target:    いい人生を送れよ
# Predicted: いい人生を送れよ
# Target:    声も変える必要が
# Predicted: 声も帰る必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空ラ大
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: チェコフはアプできるかる
# Target:    いやお前には出来ない
# Predicted: いやお前には出きない
# Target:    捨てられん大好きだろ
# Predicted: 捨てらん大好ききろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外校
# Target:    ここまでやってこられた
# Predicted: ここまでやって来られた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今ゲーなのよ
# Target:    この機械は価値がない
# Predicted: この機会は価値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 10/20: Learning rate @ 6.71e-05
# 3125/3125 [==============================] - 1002s 320ms/step - loss: 0.2516 - cer: 0.1016 - val_loss: 0.6273 - val_cer: 0.0931
# ---------------------------------------------------------------------------------------------------------------------------------
# Training
# Target:    全て私が管理しています
# Predicted: 全て私が管理理ていますす
# Target:    トリは遭難信号を発して
# Predicted: 鳥リそー難信号を発して
# Target:    女性達にそういう事なんだ
# Predicted: 女性たちにそうううこなんだ
# Target:    巨大な腫瘍があったのです
# Predicted: 巨大な腫瘍があったのです
# Target:    ルーマニア国籍となっています
# Predicted: ルーマニア国籍となっています
# Target:    要するに君たちを車に乗せ
# Predicted: 要するに君達ちを車に乗せ
# Target:    君は身体を求めるばかりで
# Predicted: 君は身体を求めるばかりで
# Target:    彼女達のビデオもここにある
# Predicted: 彼女達のビビオもここにああ
# Target:    こんにちはよろしくお願いします
# Predicted: こんにちはよろしくお願いします
# Target:    ワシントンヘラルドのバーンズです
# Predicted: ワシントンヘラルドの場ーンズです
# Target:    トーレデダビの話を聞きました
# Predicted: トーレデダビの話を聞きました
# Target:    潜水艦よ潜水艦員なの
# Predicted: 潜水艦よ潜水間人なの
# Target:    マーティンはいつも自慢してました
# Predicted: マーティンはいつも自慢してました
# Target:    これは誰にも触ってほしくない
# Predicted: これは誰にも触ってほしくない
# Target:    遺伝子が活性化されています
# Predicted: 遺伝子が活性化されています
# Target:    彼らは誰かを撃つかもしれない
# Predicted: 彼らは誰かをうつかもしれない
# Target:    私は自分の仕事をしよう
# Predicted: 私は自分の仕事をしよう
# Target:    俺は鷹のような目を持っている
# Predicted: 俺は高のような目を持っている
# Target:    で私の情報によるとね
# Predicted: で私の情報によるとね
# Target:    あなたと私ここでは無給
# Predicted: あなたと私ここでは無球
# Target:    そのリストには何人載ってるの
# Predicted: そのリストには何人載ってるの
# Target:    だからまだそういうんじゃないって
# Predicted: だからまだそういうんじゃないって
# Target:    ストリゴイは聖地には入れないわ
# Predicted: ストリゴイは世地には入れないわ
# Target:    娘を訪ねたと思ってたんだ
# Predicted: 娘を訪ねたと思ってたんだ
# Target:    警察は俺が誰だか知ってる
# Predicted: 警察は俺が誰だか知ってる
# Target:    それが段田の弔い合戦だ
# Predicted: それが段田の扉い活戦だ
# Target:    化学療法を受ける時間も
# Predicted: 化学療法を受ける時間も
# Target:    彼女は今日何をしましたか
# Predicted: 彼女は今日何をしましたか
# Target:    こんなことになって残念だけど
# Predicted: こんな事にになって残念けけど
# Target:    暗号化した思考を呼び起こす
# Predicted: 暗号化した思考を呼び起こす
# Target:    虚栄プライド罪全て捨てた
# Predicted: 虚栄プライド罪全べ捨てた
# Target:    ホワイトハウスでパーティーがあり
# Predicted: ホワイトハウスでパーティーがありあ
# Target:    寄生虫はすごいと思います
# Predicted: 寄成中はすごいと思います
# Target:    たぶんこの町が流された事ね
# Predicted: たぶんこの町が流されたこね
# Target:    私の弟も引き込まれた
# Predicted: 私の弟もききままれた
# Target:    私に黙ってあなたにこれを
# Predicted: 私に黙ってあなたにこれを
# Target:    同僚の一人が無能なので
# Predicted: 同僚の一人が無能ななで
# Target:    ブラッドの歯の型をベースにして
# Predicted: ブラッドの歯の方をベースにして
# Target:    彼の話は本当でしょうか
# Predicted: 彼の話は本当でしょうか
# Target:    彼は自分の子供を愛します
# Predicted: 彼は自分の子供を愛します
# Target:    命に別条はなさそうです
# Predicted: 命に別場はなさそうです
# Target:    ハレンチで怠惰なブタでいる罪
# Predicted: ハレンチで台惰だブブタるる罪
# Target:    また会えたなヘンリーフィッツロイ
# Predicted: また会えたなヘンリーフィツロロイロ
# Target:    事情を説明してくださいねっ
# Predicted: 事情を説明して下ださいね
# Target:    片方の条件を良くしたら
# Predicted: 片方の条件をよくしたら
# Target:    皿洗いを手伝わせて下さい
# Predicted: 皿洗洗い手伝わせてください
# Target:    ちょっと会話したかっただけだよ
# Predicted: ちょっと会話したかっただけだよ
# Target:    正常な発信信号とは
# Predicted: 正常な発信信号とは
# Target:    この近所には人が住んでるの
# Predicted: この近所には人が住んでるの
# Target:    客はもっと馬力を欲しがってる
# Predicted: 客はもっとバ力を欲しがてて
# Target:    人が互いに関係する上で
# Predicted: 人が互いに関係するでで
# Target:    マニュアルってものがあるようです
# Predicted: マニュアルってものがあるようです
# Target:    君がどんな調査をしようとも
# Predicted: 君がどんな調査をしようとも
# Target:    ブラットのものはここに入ってる
# Predicted: ブラットのものはここに入ってる
# Target:    彼はあなたが死んだと思ってる
# Predicted: 彼はあなたが死んだと思ってる
# Target:    時にはつかみどころがないけれど
# Predicted: 時には掴みどこがろななけ
# Target:    それは地震装置の試作品だ
# Predicted: それは自震装置の作作品だ
# Target:    私に直接報告して
# Predicted: 私に直接報告して
# Target:    なぜならば高度社会はいつも
# Predicted: なぜならば高度社会はいつも
# Target:    そんなことには慣れていそうだけど
# Predicted: そんな事とに慣慣れていうだだけど
# Target:    リーなんで弾が入ってなんだよ
# Predicted: リー何んで弾が入ってなんだよ
# Target:    それでコーヒーミルクと砂糖入り
# Predicted: それでコーヒーミルクと砂糖入り
# Target:    部屋捜しは苦労することがある
# Predicted: 部屋探しは苦すするこががある
# Target:    何があっても出るなすぐに戻る
# Predicted: 何があってもデるなすぐに戻る
#
# Validation
# Target:    甲の損は乙の得
# Predicted: 公のソンはのの得
# Target:    あなたのチップを作り
# Predicted: あなたのチップを作り
# Target:    ロビンソン浮上しろ
# Predicted: ロビンソン婦上しろ
# Target:    そこへ歩いて行けます
# Predicted: そこへ歩いていけます
# Target:    やりたければやればいい
# Predicted: やりたければやればいい
# Target:    荒削りな味がする
# Predicted: あら削ずり味味がる
# Target:    ほんとうにおいしいです
# Predicted: 本当においしいです
# Target:    年初からの日数
# Predicted: 年所からの日数
# Target:    最悪ねお気の毒に
# Predicted: 最悪ねおきの毒に
# Target:    うんじゃあ早くやろう
# Predicted: うんじゃあ早く野郎
# Target:    己の真価を見せよ
# Predicted: 己の進化を見せよ
# Target:    彼は助けてくれない
# Predicted: 彼は助けてくれない
# Target:    何がいけなかったんだ
# Predicted: 何が行けなかったんだ
# Target:    大衆へより強く
# Predicted: 大衆へより強く
# Target:    それはそうかもしれんが
# Predicted: それはそうかもしれんが
# Target:    一緒に入ってやる
# Predicted: 一緒に入ってやる
# Target:    そんなに驚かないの
# Predicted: そんなに驚かないの
# Target:    だって君はやせてるし
# Predicted: だって君は痩せてるし
# Target:    この船を飛ばせるのか
# Predicted: この船を飛ばせるのか
# Target:    こんにちは田名辺さん
# Predicted: こんにちはたなヘェんん
# Target:    えぇマキャリスターです
# Predicted: えママキャススーですス
# Target:    レース用の箒だよ
# Predicted: レース用の方箒だよ
# Target:    もう一回いってみて
# Predicted: もう一回言ってみて
# Target:    俺の演技から失せろ
# Predicted: 俺の演技から失せろ
# Target:    今日の夜空を見つめ
# Predicted: 今日の夜空を見つつ
# Target:    彼はとても厳しいわ
# Predicted: 彼はとても厳しいわ
# Target:    アマチュアと呼ばせない
# Predicted: アマチュアと呼ばせない
# Target:    他の方法を探す
# Predicted: 他の方法を探す
# Target:    私が悪いのです
# Predicted: 私が悪いのです
# Target:    書き留めることによって
# Predicted: 書き留めることによって
# Target:    それだけ言いたかったの
# Predicted: それだけ言いたかったの
# Target:    それは残念なことだ
# Predicted: それは残念な事だ
# Target:    ギャングですってだから
# Predicted: ギャングですってだから
# Target:    話すわでも今はまだ
# Predicted: 話すわでも今はまだ
# Target:    引き離された父親
# Predicted: 引き離された父親
# Target:    誤解しないでください
# Predicted: 誤解しないでください
# Target:    道路が欲しいと言えば
# Predicted: 道路が欲しいと言えば
# Target:    ジュースうまいなそうか
# Predicted: 銃数マいなそうか
# Target:    君こそ知ってるだろう
# Predicted: 君こそ知ってるだろう
# Target:    ここにいるべきじゃない
# Predicted: ここにいるべきじゃない
# Target:    なんだそのサンバイザー
# Predicted: 何だそのサンバイザー
# Target:    いい人生を送れよ
# Predicted: いい人生を送れよ
# Target:    声も変える必要が
# Predicted: 声も変え必要が
# Target:    果てしない空と大地
# Predicted: 果てしない空と第
# Target:    俺がそういったからだ
# Predicted: 俺がそう言ったからだ
# Target:    約束しますジャック
# Predicted: 約束しますジャック
# Target:    彼は捜査中です
# Predicted: 彼は捜査中です
# Target:    彼女は壁の花だ
# Predicted: 彼女は壁の花だ
# Target:    チェコフワープできるか
# Predicted: チェコフワアプできるかる
# Target:    いやお前には出来ない
# Predicted: いやお前には出きない
# Target:    捨てられん大好きだろ
# Predicted: 捨てら連大好きだろ
# Target:    リーダーシップ外交
# Predicted: リーダーシップ外交
# Target:    ここまでやってこられた
# Predicted: ここまでやって来られた
# Target:    私が連れて行こう
# Predicted: 私が連れて行こう
# Target:    ここに来て助けてくれ
# Predicted: ここに来て助けてくれ
# Target:    それには時間がかかる
# Predicted: それには時間がかかる
# Target:    この病気にかかると
# Predicted: この病気にかかると
# Target:    協力的ですよ
# Predicted: 協力的ですよ
# Target:    ジャッジメントブローを
# Predicted: ジャッジメントブローを
# Target:    ちょっと今ゲイなのよ
# Predicted: ちょっと今げーなのよ
# Target:    この機械は価値がない
# Predicted: この機械は価値がない
# Target:    空を見上げたポーズで
# Predicted: 空を見上げたポーズで
# Target:    娘は死んだわリック
# Predicted: 娘は死んだわリック
# Target:    別の時代にいるのよ
# Predicted: 別の時代にいるのよ
# ---------------------------------------------------------------------------------------------------------------------------------
# Epoch 11/20: Learning rate @ 5.86e-05
#   68/3125 [..............................] - ETA: 15:06 - loss: 0.3328 - cer: 0.0858
